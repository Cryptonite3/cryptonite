# %% [markdown]
# # Data Cleaning

# %%
# Importing necessary libraries
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %% [markdown]
# ## All currencies dataset

# %%
df = pd.read_csv(
    filepath_or_buffer = '../data/all_currencies_table.csv',
    index_col = 0
)
df.head()
# Out:
#                 name symbol    market_cap        price  circulating_supply  \
# number
# 1            Bitcoin    BTC  1.507030e+11  8940.740000        1.685576e+07
# 2           Ethereum    ETH  8.754697e+10   897.729000        9.752049e+07
# 3             Ripple    XRP  4.062771e+10     1.041490        3.900922e+10
# 4       Bitcoin Cash    BCH  2.294639e+10  1353.040000        1.695914e+07
# 5            Cardano    ADA  1.163729e+10     0.448847        2.592707e+10
#
#          volume_24hr    1h    24h     7d
# number
# 1       8.103300e+09 -0.63  11.22   3.58
# 2       3.062570e+09 -0.41  11.99  -0.25
# 3       2.504810e+09 -0.37  32.86  23.94
# 4       1.149550e+09  0.11   7.89  18.32
# 5       7.603720e+08 -0.71  27.62  23.61

# %% [markdown]
# ### Metadata

# %% [markdown]
# - __Name__ -> Name of the CryptoCurrency.
# - __Symbol__ -> Symbol of the CrytoCurrency.
# - __Market Capitalization(in \$)__ -> The total market value of a cryptocurrency's circulating supply.
# $Market Cap = Current Price * Circulating Supply.$
# - __Price(in \$)__ -> The current price at which an asset or service can be bought or sold.
# - __Circulating Supply__ -> The amount of coins that are circulating in the market and are in public hands.
# - __Volume 24-Hour(in \$)__ -> A measure of how much of a cryptocurrency was traded in the last 24 hours.
# - __1 Hour(in \%)__ -> Trend for the last hour.
# - __24 Hours(in \%)__ -> Trend for the last 24 hours.
# - __7 days(in \%)__ -> Trend for the last 7 days.

# %%
df.tail()
# Out:
#                     name symbol  market_cap       price  circulating_supply  \
# number
# 1512       LiteCoin Gold    LTG         NaN    0.006132                 NaN
# 1513                eBIT   EBIT         NaN    0.004195                 NaN
# 1514           Faceblock    FBL         NaN    0.003230                 NaN
# 1515           Farstcoin   FRCT         NaN         NaN                 NaN
# 1516    Decentralized...   DUBI         NaN  123.813000                 NaN
#
#         volume_24hr  1h    24h     7d
# number
# 1512            NaN NaN   8.37 -23.59
# 1513            NaN NaN    NaN -38.75
# 1514            NaN NaN    NaN -79.33
# 1515            NaN NaN    NaN    NaN
# 1516            NaN NaN  10.87  11.25

# %% [markdown]
# From the above dataset, we can tell that name and symbol are all just suitable identifiers for data points or in other words indexes. We can prove the same by checking if they're collectively unique. If not, we'll have to get rid of duplicates as they add ambiguity to the dataset.

# %%
temp = df[['name', 'symbol']].apply(
    func = '_'.join,
    axis = 1
).value_counts()
temp[temp > 1]
# Out:
# EncryptoTel [..._ETT    2
# dtype: int64

# %% [markdown]
# As we can see, EncryptoTel is the only data point that has duplicates.

# %%
df[df.symbol == 'ETT']
# Out:
#                     name symbol    market_cap     price  circulating_supply  \
# number
# 493     EncryptoTel [...    ETT  7.652512e+06  0.123167          62131189.6
# 1389    EncryptoTel [...    ETT           NaN  0.079232                 NaN
#
#         volume_24hr    1h    24h     7d
# number
# 493         863.626 -1.53  56.02  38.85
# 1389        949.529 -1.23   6.45  -2.17

# %% [markdown]
# We can choose to delete the 2nd ETT as it has NaNs and also makes our indexes legitimate.

# %%
df.drop(
    index = 1389,
    inplace = True
)

# %%
df[df.symbol == 'ETT']
# Out:
#                     name symbol    market_cap     price  circulating_supply  \
# number
# 493     EncryptoTel [...    ETT  7.652512e+06  0.123167          62131189.6
#
#         volume_24hr    1h    24h     7d
# number
# 493         863.626 -1.53  56.02  38.85

# %% [markdown]
# As we can see, our issue is resolved.
# Now we can change our index to this new and more appropriate one.

# %%
df.set_index(
    keys = ['name', 'symbol'],
    inplace = True
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1515 entries, ('Bitcoin', 'BTC') to ('Decentralized...', 'DUBI')
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   market_cap          1155 non-null   float64
#  1   price               1513 non-null   float64
#  2   circulating_supply  1131 non-null   float64
#  3   volume_24hr         1501 non-null   float64
#  4   1h                  1451 non-null   float64
#  5   24h                 1464 non-null   float64
#  6   7d                  1477 non-null   float64
# dtypes: float64(7)
# memory usage: 176.8+ KB

# %%
df.shape
# Out:
# (1515, 7)

# %%
df.apply(
    func = lambda l: l.isna().sum(),
    axis = 1
).value_counts()
# Out:
# 0    1073
# 2     329
# 1      57
# 3      35
# 4      16
# 5       2
# 6       2
# 7       1
# dtype: int64

# %% [markdown]
# We can choose to drop data with more than 2 missing values and apply filler techniques for the rest.

# %%
fig = msno.bar(
    df,
    color = 'green'
)
plt.show()

# %% [markdown]
# Leaving market_cap and circulating_supply, the number of missing values in the other features is quite low.

# %%
ax = msno.matrix(
    df,
    color = (0, 0, 0.6),
    sparkline = False
)
plt.show()

# %% [markdown]
# Here, we can see that there is high correspondence of nullity between market_cap and circulating_supply.
# For now lets fill all the other features with their respective means.

# %%
df[df.price.isna()]
# Out:
#                   market_cap  price  circulating_supply  volume_24hr  1h  24h  \
# name      symbol
# LLToken   LLT            NaN    NaN                 NaN          0.0 NaN  NaN
# Farstcoin FRCT           NaN    NaN                 NaN          NaN NaN  NaN
#
#                   7d
# name      symbol
# LLToken   LLT    NaN
# Farstcoin FRCT   NaN

# %% [markdown]
# For now we can ignore the price feature as the 2 data points will eventually be dropped eitherways.

# %%
def filler(l):
    mean = l.mean()
    l.fillna(mean, inplace = True)
    return l
names = df.columns[3:]
print(names)
df[names] = df[names].apply(func = filler)
# Out:
# Index(['volume_24hr', '1h', '24h', '7d'], dtype='object')

# %%
df.tail()
# Out:
#                          market_cap       price  circulating_supply  \
# name             symbol
# LiteCoin Gold    LTG            NaN    0.006132                 NaN
# eBIT             EBIT           NaN    0.004195                 NaN
# Faceblock        FBL            NaN    0.003230                 NaN
# Farstcoin        FRCT           NaN         NaN                 NaN
# Decentralized... DUBI           NaN  123.813000                 NaN
#
#                           volume_24hr        1h       24h         7d
# name             symbol
# LiteCoin Gold    LTG     1.660388e+07 -0.603777   8.37000 -23.590000
# eBIT             EBIT    1.660388e+07 -0.603777  14.08877 -38.750000
# Faceblock        FBL     1.660388e+07 -0.603777  14.08877 -79.330000
# Farstcoin        FRCT    1.660388e+07 -0.603777  14.08877   5.110393
# Decentralized... DUBI    1.660388e+07 -0.603777  10.87000  11.250000

# %% [markdown]
# Now that NaNs are dealt with for the other features, we can look into circulating_supply and market_cap.
# Both these features are related through an equation that goes like -
# $Market Cap = Current Price * Circulating Supply.$
# It can be used to fill the NaNs in circulating_supply.
# Next, we can drop the common null data points between the two.

# %%
df['circulating_supply'] = df.apply(
    func = lambda l: l[0] / l[1] if pd.isna(l[2]) else l[2],
    axis = 1
)
df.dropna(inplace = True)
df.shape
# Out:
# (1155, 7)

# %% [markdown]
# We've gotten rid of 360 data points and applied filler methods for the remaining NaNs.
# Lets take a look at the bar chart to see if they're any more remaining.

# %%
fig = msno.bar(
    df,
    color = 'green'
)
plt.show()

# %% [markdown]
# Now that we've gotten rid of all the NaNs, We can look to rename our features for ease of access during EDA.

# %%
df.rename(
    columns = {
        'market_cap': 'Market',
        'price': 'Price',
        'circulating_supply': 'Circulate',
        'volume_24hr': 'Volume',
        '1h': 'Hourly',
        '24h': 'Daily',
        '7d': 'Weekly'
    },
    inplace = True
)
df.index.rename(names = ['Name', 'Symbol'], inplace = True)
df.head()
# Out:
#                            Market        Price     Circulate        Volume  \
# Name         Symbol
# Bitcoin      BTC     1.507030e+11  8940.740000  1.685576e+07  8.103300e+09
# Ethereum     ETH     8.754697e+10   897.729000  9.752049e+07  3.062570e+09
# Ripple       XRP     4.062771e+10     1.041490  3.900922e+10  2.504810e+09
# Bitcoin Cash BCH     2.294639e+10  1353.040000  1.695914e+07  1.149550e+09
# Cardano      ADA     1.163729e+10     0.448847  2.592707e+10  7.603720e+08
#
#                      Hourly  Daily  Weekly
# Name         Symbol
# Bitcoin      BTC      -0.63  11.22    3.58
# Ethereum     ETH      -0.41  11.99   -0.25
# Ripple       XRP      -0.37  32.86   23.94
# Bitcoin Cash BCH       0.11   7.89   18.32
# Cardano      ADA      -0.71  27.62   23.61

# %%
df.to_csv(path_or_buf = '../data/all_currencies_clean_table.csv')

# %% [markdown]
# ## CryptoCurrency Prices by Date Dataset

# %%
trend = pd.read_csv(
    filepath_or_buffer = '../data/cryptocurrency_prices_by_date.csv'
)
trend.head()
# Out:
#   currency           date     price
# 0       0x  1502892561000  0.111725
# 1       0x  1502982305000  0.211486
# 2       0x  1503068692000  0.283789
# 3       0x  1503155108000  0.511434
# 4       0x  1503241503000  0.429522

# %% [markdown]
# For this dataset, we could start off by bringing the date back to a usual format.

# %%
trend['date'] = pd.to_datetime(
    arg = trend.date,
    unit = 'ms'
).dt.strftime('%d-%m-%Y %H:%M:%S')
trend.tail()
# Out:
#        currency                 date     price
# 657311  zurcoin  04-02-2018 07:09:10  0.003254
# 657312  zurcoin  05-02-2018 07:09:10  0.002774
# 657313  zurcoin  06-02-2018 07:44:10  0.001986
# 657314  zurcoin  09-02-2018 08:29:06  0.002684
# 657315  zurcoin  10-02-2018 03:54:06  0.002325

# %% [markdown]
# We can ignore quite a few data points from this dataset.
# And limit our analysis to the ones present in the previous dataset that have not been wiped out because of NaNs.

# %%
li = list(pd.Series(df.index.get_level_values('Name')).apply(str.lower))
mask = trend.currency.apply(lambda l: l.lower() in li)
temp = trend[mask]

# %%
temp[temp.currency == 'bitcoin']
# Out:
#       currency                 date    price
# 64167  bitcoin  28-04-2013 18:47:21   135.30
# 64168  bitcoin  29-04-2013 18:45:01   141.96
# 64169  bitcoin  30-04-2013 18:45:02   135.30
# 64170  bitcoin  01-05-2013 18:45:02   117.00
# 64171  bitcoin  02-05-2013 19:20:01   103.43
# ...        ...                  ...      ...
# 65895  bitcoin  06-02-2018 04:39:28  6252.44
# 65896  bitcoin  07-02-2018 04:44:23  7386.63
# 65897  bitcoin  08-02-2018 04:44:23  8179.93
# 65898  bitcoin  09-02-2018 04:44:29  8003.77
# 65899  bitcoin  10-02-2018 03:54:27  9037.51
#
# [1733 rows x 3 columns]

# %%
set(temp.currency).difference(set(li))
# Out:
# set()

# %%
'bitcoin' in li
# Out:
# False

# %%
li.sort()

# %%
li[500:]
# Out:
# ['gridcoin',
#  'grimcoin',
#  'groestlcoin',
#  'growers inter...',
#  'guccionecoin',
#  'gulden',
#  'guncoin',
#  'gxshares',
#  'hacken',
#  'hackspace cap...',
#  'halcyon',
#  'happycoin',
#  'harmonycoin',
#  'hawala.today',
#  'healthywormcoin',
#  'heat',
#  'hedge',
#  'helleniccoin',
#  'hellogold',
#  'hempcoin',
#  'hempcoin',
#  'herocoin',
#  'hexx',
#  'hicoin',
#  'high performa...',
#  'high voltage',
#  'hitcoin',
#  'hive',
#  'hobonickels',
#  'hodlcoin',
#  'hollywoodcoin',
#  'homeblockcoin',
#  'honey',
#  'hshare',
#  'htmlcoin',
#  'hubii network',
#  'humaniq',
#  'huntercoin',
#  'hush',
#  'hyperstake',
#  'i/o coin',
#  'i0coin',
#  'ibank',
#  'ico openledger',
#  'icobid',
#  'icoin',
#  'icon',
#  'iconic',
#  'iconomi',
#  'icos',
#  'idice',
#  'iethereum',
#  'iexec rlc',
#  'ignis',
#  'impact',
#  'impulsecoin',
#  'incakoin',
#  'incent',
#  'indahash',
#  'independent m...',
#  'indorse token',
#  'inflationcoin',
#  'influxcoin',
#  'ink',
#  'innova',
#  'inpay',
#  'ins ecosystem',
#  'insanecoin',
#  'insurepal',
#  'intelligent t...',
#  'intensecoin',
#  'internet node...',
#  'internet of p...',
#  'internxt',
#  'interstellar ...',
#  'investfeed',
#  'ion',
#  'iostoken',
#  'iot chain',
#  'iota',
#  'islacoin',
#  'iticoin',
#  'iungo',
#  'ixcoin',
#  'ixledger',
#  'janus',
#  'javascript token',
#  'jetcoin',
#  'jewels',
#  'jin coin',
#  'jinn',
#  'jobscoin',
#  'joincoin',
#  'joulecoin',
#  'karbo',
#  'karma',
#  'kayicoin',
#  'kekcoin',
#  'kickcoin',
#  'kilocoin',
#  'kin',
#  'kingn coin',
#  'kobocoin',
#  'kolion',
#  'komodo',
#  'kore',
#  'kronecoin',
#  'kubera coin',
#  'kucoin shares',
#  'kurrent',
#  'kushcoin',
#  'kyber network',
#  'lamden',
#  'lampix',
#  'lanacoin',
#  'latoken',
#  'lbry credits',
#  'leacoin',
#  'legends room',
#  'lendconnect',
#  'leocoin',
#  'letitride',
#  'leverj',
#  'leviarcoin',
#  'levoplus',
#  'life',
#  'linda',
#  'link platform',
#  'linx',
#  'lisk',
#  'litebar',
#  'litebitcoin',
#  'litecoin',
#  'litecoin plus',
#  'litecoin ultra',
#  'litecred',
#  'litedoge',
#  'lockchain',
#  'lomocoin',
#  'loopring',
#  'luckchain',
#  'luna coin',
#  'lunyr',
#  'luxcoin',
#  'lykke',
#  'machinecoin',
#  'macron',
#  'madcoin',
#  'maecenas',
#  'magi',
#  'magiccoin',
#  'magnet',
#  'magnum',
#  'maidsafecoin',
#  'maker',
#  'mao zedong',
#  'marijuanacoin',
#  'marscoin',
#  'martexcoin',
#  'master swiscoin',
#  'masternodecoin',
#  'matchpool',
#  'maxcoin',
#  'maza',
#  'mcap',
#  'medibloc',
#  'medishares',
#  'megacoin',
#  'melon',
#  'memetic / pep...',
#  'mercury',
#  'mercury protocol',
#  'metal',
#  'metal music coin',
#  'metalcoin',
#  'metaverse etp',
#  'micromoney',
#  'milocoin',
#  'mincoin',
#  'mindcoin',
#  'minereum',
#  "miners' rewar...",
#  'mineum',
#  'minexcoin',
#  'mintcoin',
#  'mobilego',
#  'modum',
#  'moeda loyalty...',
#  'moin',
#  'mojocoin',
#  'monaco',
#  'monacoin',
#  'monero',
#  'monetaryunit',
#  'monetha',
#  'money',
#  'monkey project',
#  'monoeci',
#  'monster byte',
#  'mooncoin',
#  'mothership',
#  'motocoin',
#  'musicoin',
#  'mustangcoin',
#  'mybit token',
#  'myriad',
#  'mysterium',
#  'mywish',
#  'naga',
#  'namecoin',
#  'nano',
#  'nav coin',
#  'neblio',
#  'nebulas',
#  'nekonium',
#  'nem',
#  'neo',
#  'neoscoin',
#  'netcoin',
#  'netko',
#  'network token',
#  'neumark',
#  'neuro',
#  'neutron',
#  'nevacoin',
#  'neverdie',
#  'newbium',
#  'newyorkcoin',
#  'nexium',
#  'nexus',
#  'nimfamoney',
#  'nimiq',
#  'noblecoin',
#  'nodecoin',
#  'nolimitcoin',
#  'novacoin',
#  'nubits',
#  'nuls',
#  'numeraire',
#  'nushares',
#  'nvo',
#  'nxt',
#  'nyancoin',
#  'oax',
#  'obits',
#  'obsidian',
#  'oceanlab',
#  'octanox',
#  'octocoin',
#  'odyssey',
#  'okcash',
#  'olympus labs',
#  'omisego',
#  'omni',
#  'oneroot network',
#  'ong.social',
#  'onix',
#  'op coin',
#  'opal',
#  'open trading ...',
#  'opus',
#  'oraclechain',
#  'orbitcoin',
#  'origintrail',
#  'orlycoin',
#  'ormeus coin',
#  'osmiumcoin',
#  'oxycoin',
#  'oyster',
#  'p7coin',
#  'paccoin',
#  'pakcoin',
#  'pandacoin',
#  'paragon',
#  'parallelcoin',
#  'pareto network',
#  'parkbyte',
#  'particl',
#  'pascal coin',
#  'pascal lite',
#  'patientory',
#  'paycoin',
#  'paycon',
#  'payfair',
#  'paypex',
#  'paypie',
#  'peercoin',
#  'peerplays',
#  'pepe cash',
#  'pesetacoin',
#  'petrodollar',
#  'philosopher s...',
#  'phoenixcoin',
#  'phore',
#  'photon',
#  'piecoin',
#  'piggycoin',
#  'pillar',
#  'pinkcoin',
#  'pioneer coin',
#  'piplcoin',
#  'pirl',
#  'pivx',
#  'pizzacoin',
#  'platinumbar',
#  'playercoin',
#  'playkey',
#  'plncoin',
#  'pluscoin',
#  'pluton',
#  'po.et',
#  'polis',
#  'polybius',
#  'ponzicoin',
#  'popularcoin',
#  'populous',
#  'posex',
#  'postcoin',
#  'postoken',
#  'posw coin',
#  'potcoin',
#  'power ledger',
#  'prcoin',
#  'presearch',
#  'primalbase token',
#  'primas',
#  'prime-xi',
#  'primecoin',
#  'printerium',
#  'privatix',
#  'prizm',
#  'prochain',
#  'procurrency',
#  'profile utili...',
#  'project decorum',
#  'project-x',
#  'propy',
#  'prospectors gold',
#  'prototanium',
#  'publica',
#  'pulse',
#  'pura',
#  'pure',
#  'purevidz',
#  'putincoin',
#  'px',
#  'pylon network',
#  'qash',
#  'qbao',
#  'qbic',
#  'qlink',
#  'qtum',
#  'quantstamp',
#  'quantum',
#  'quantum resis...',
#  'quark',
#  'quatloo',
#  'quazarcoin',
#  'qubitcoin',
#  'quebecoin',
#  'qunqun',
#  'qvolta',
#  'qwark',
#  'radium',
#  'raiden networ...',
#  'rasputin onli...',
#  'ratecoin',
#  'rawcoin',
#  'rchain',
#  'real',
#  'red pulse',
#  'redcoin',
#  'reddcoin',
#  'reecoin',
#  'regalcoin',
#  'remicoin',
#  'renos',
#  'request network',
#  'revain',
#  'revolvercoin',
#  'rex',
#  'rialto',
#  'ride my car',
#  'riecoin',
#  'rimbit',
#  'ripio credit ...',
#  'ripple',
#  'ripto bux',
#  'rise',
#  'rivetz',
#  'ronpaulcoin',
#  'roofs',
#  'roulettetoken',
#  'royal kingdom...',
#  'rsgpcoin',
#  'rubies',
#  'rubycoin',
#  'rupaya',
#  'rupee',
#  'russiacoin',
#  'russian miner...',
#  'rustbits',
#  'sacoin',
#  'safe exchange...',
#  'sagacoin',
#  'salt',
#  'salus',
#  'santiment net...',
#  'sativacoin',
#  'satoshimadness',
#  'save and gain',
#  'scorecoin',
#  'secretcoin',
#  'securecoin',
#  'selfiecoin',
#  'selfkey',
#  'senderon',
#  'sequence',
#  'sexcoin',
#  'shadow token',
#  'shadowcash',
#  'sharechain',
#  'shield',
#  'shift',
#  'shilling',
#  'shorty',
#  'siacoin',
#  'sibcoin',
#  'signatum',
#  'simple token',
#  'singulardtv',
#  'singularitynet',
#  'sirin labs token',
#  'sixeleven',
#  'skeincoin',
#  'skincoin',
#  'skycoin',
#  'slevin',
#  'smart investm...',
#  'smartbillions',
#  'smartcash',
#  'smartcoin',
#  'smileycoin',
#  'snovio',
#  'soarcoin',
#  'social',
#  'social send',
#  'socialcoin',
#  'soilcoin',
#  'sojourn',
#  'solarcoin',
#  'solarflarecoin',
#  'solaris',
#  'soma',
#  'songcoin',
#  'sonm',
#  'sono',
#  'sooncoin',
#  'sophiatx',
#  'sovereign hero',
#  'spacecoin',
#  'spankchain',
#  'spectre.ai di...',
#  'spectre.ai ut...',
#  'spectrecoin',
#  'speedcash',
#  'sphere',
#  'sportyco',
#  'spots',
#  'spreadcoin',
#  'sprouts',
#  'sproutsextreme',
#  'starbase',
#  'starcash network',
#  'starcredits',
#  'starta',
#  'startcoin',
#  'status',
#  'stealthcoin',
#  'steem',
#  'steem dollars',
#  'stellar',
#  'steneum coin',
#  'steps',
#  'sterlingcoin',
#  'storj',
#  'storm',
#  'stox',
#  'straks',
#  'stratis',
#  'streamr datacoin',
#  'substratum',
#  'sugar exchange',
#  'sumokoin',
#  'suncontract',
#  'supercoin',
#  'supernet',
#  'suretly',
#  'swagbucks',
#  'swarm city',
#  'swftcoin',
#  'swing',
#  'sydpak',
#  'syndicate',
#  'synereo',
#  'synergy',
#  'syscoin',
#  'taas',
#  'tagcoin',
#  'tagrcoin',
#  'tajcoin',
#  'tao',
#  'target coin',
#  'tattoocoin (s...',
#  'tekcoin',
#  'telcoin',
#  'tenx',
#  'terracoin',
#  'teslacoin',
#  'tether',
#  'the champcoin',
#  'thegcccoin',
#  'theresa may coin',
#  'theta token',
#  'tierion',
#  'ties network',
#  'tigercoin',
#  'time new bank',
#  'titcoin',
#  'tittiecoin',
#  'toacoin',
#  'tokencard',
#  'tokes',
#  'tokyo',
#  'torcoin',
#  'tracto',
#  'trade token',
#  'transfercoin',
#  'trezarcoin',
#  'triangles',
#  'trident group',
#  'triggers',
#  'trinity netwo...',
#  'tristar coin',
#  'trollcoin',
#  'tron',
#  'truckcoin',
#  'trueflip',
#  'trumpcoin',
#  'trustplus',
#  'tychocoin',
#  'ubiq',
#  'ufo coin',
#  'ulatech',
#  'ultimate secu...',
#  'ultracoin',
#  'unbreakablecoin',
#  'unicoin',
#  'unify',
#  'unikoin gold',
#  'unitus',
#  'unity ingot',
#  'universal cur...',
#  'universe',
#  'unobtanium',
#  'unrealcoin',
#  'upfiring',
#  'uquid coin',
#  'uro',
#  'useless ether...',
#  'utrust',
#  'valorbit',
#  'vaperscoin',
#  'vault coin',
#  'vcash',
#  'vechain',
#  'vectorai',
#  'veltor',
#  'verge',
#  'vericoin',
#  'verify',
#  'veritaseum',
#  'veriumreserve',
#  'veros',
#  'version',
#  'vertcoin',
#  'viacoin',
#  'vibe',
#  'viberate',
#  'vip tokens',
#  'virta unique ...',
#  'virtacoin',
#  'virtacoinplus',
#  'virtualcoin',
#  'visio',
#  'viuly',
#  'vivo',
#  'voise',
#  'votecoin',
#  'voxels',
#  'vslice',
#  'vsync',
#  'vtorrent',
#  'wabi',
#  'wagerr',
#  'walton',
#  'wandx',
#  'warp',
#  'waves',
#  'waves communi...',
#  'wavesgo',
#  'wax',
#  'wayguide',
#  'wetrust',
#  'whalecoin',
#  'whitecoin',
#  'wild beast block',
#  'wild crypto',
#  'wings',
#  'womencoin',
#  'woodcoin',
#  'worldcoin',
#  'worldcore',
#  'x-coin',
#  'xaurum',
#  'xenon',
#  'xgox',
#  'xios',
#  'xonecoin',
#  'xplay',
#  'xtrabytes',
#  'yacoin',
#  'yellow token',
#  'yenten',
#  'yocoin',
#  'yoyow',
#  'zayedcoin',
#  'zcash',
#  'zclassic',
#  'zcoin',
#  'zeitcoin',
#  'zencash',
#  'zennies',
#  'zephyr',
#  'zero',
#  'zetacoin',
#  'zetamicron',
#  'zeusshield',
#  'zilliqa',
#  'zlancer',
#  'zoin',
#  'zonecoin',
#  'zozocoin',
#  'zrcoin',
#  'zurcoin']

# %%
list(filter(lambda l: '...' in l, li))
# Out:
# ['accelerator n...',
#  'advanced inte...',
#  'basic attenti...',
#  'billionaire t...',
#  'blockmason cr...',
#  'circuits of v...',
#  'commodity ad ...',
#  'cryptoworldx ...',
#  'cthulhu offer...',
#  'digital money...',
#  'digitaldevelo...',
#  'dynamic tradi...',
#  'encryptotel [...',
#  'ethereum movi...',
#  'experience po...',
#  'global curren...',
#  'gold pressed ...',
#  'growers inter...',
#  'hackspace cap...',
#  'high performa...',
#  'independent m...',
#  'intelligent t...',
#  'internet node...',
#  'internet of p...',
#  'interstellar ...',
#  'memetic / pep...',
#  "miners' rewar...",
#  'moeda loyalty...',
#  'open trading ...',
#  'philosopher s...',
#  'profile utili...',
#  'quantum resis...',
#  'raiden networ...',
#  'rasputin onli...',
#  'ripio credit ...',
#  'royal kingdom...',
#  'russian miner...',
#  'safe exchange...',
#  'santiment net...',
#  'smart investm...',
#  'spectre.ai di...',
#  'spectre.ai ut...',
#  'tattoocoin (s...',
#  'trinity netwo...',
#  'ultimate secu...',
#  'universal cur...',
#  'useless ether...',
#  'virta unique ...',
#  'waves communi...']

# %%
temp.currency.unique()
# Out:
# array(['0x', '2give', '42-coin', '808coin', '8bit', 'abjcoin', 'abncoin',
#        'ace', 'achain', 'acoin', 'adcoin', 'adelphoi', 'adshares',
#        'adtoken', 'adzcoin', 'aelf', 'aeon', 'aerium', 'aeron',
#        'aeternity', 'agrolifecoin', 'aichain', 'aigang', 'aion',
#        'airswap', 'airtoken', 'alis', 'allion', 'allsafe', 'alqo',
#        'ambercoin', 'amsterdamcoin', 'anarchistsprime', 'anoncoin',
#        'antibitcoin', 'antilitecoin', 'appcoins', 'apx', 'aquariuscoin',
#        'aragon', 'arbit', 'arcticcoin', 'ardor', 'argentum', 'argus',
#        'aricoin', 'ark', 'artbyte', 'asch', 'asiacoin', 'asiadigicoin',
#        'astro', 'atbcoin', 'atlant', 'atmos', 'audiocoin', 'augur',
#        'auroracoin', 'aurumcoin', 'authorship', 'autonio', 'aventus',
#        'bancor', 'bankcoin', 'bata', 'bcap', 'beatcoin', 'benjirolls',
#        'berncash', 'biblepay', 'bigup', 'billarycoin', 'biobar',
#        'bipcoin', 'bismuth', 'bit20', 'bitasean', 'bitbar', 'bitbay',
#        'bitboost', 'bitbtc', 'bitcedi', 'bitclave', 'bitcloud', 'bitcny',
#        'bitcoal', 'bitcoin', 'bitcoindark', 'bitcoinz', 'bitconnect',
#        'bitcore', 'bitcrystals', 'bitcurrency', 'bitdeal', 'bitdegree',
#        'bitdice', 'biteur', 'bitgem', 'bitgold', 'bitmark', 'bitquark',
#        'bitqy', 'bitradio', 'bitsend', 'bitshares', 'bitsilver',
#        'bitstar', 'bittokens', 'bitusd', 'bitvolt', 'bitz', 'bitzeny',
#        'blackcoin', 'blackmoon', 'blackstar', 'blakecoin', 'blakestar',
#        'blazecoin', 'blitzcash', 'blockcat', 'blocknet', 'blockpay',
#        'blockpool', 'blockport', 'blocktix', 'blockv', 'bluecoin',
#        'bluzelle', 'bnrtxcoin', 'bodhi', 'bolenum', 'bolivarcoin',
#        'bonpay', 'boolberry', 'bounty0x', 'bowhead', 'bowscoin',
#        'braincoin', 'bread', 'breakout', 'briacoin', 'bridgecoin',
#        'britcoin', 'btctalkcoin', 'btsr', 'bulwark', 'bumbacoin',
#        'bunnycoin', 'burst', 'buzzcoin', 'bytecent', 'bytom', 'c-bit',
#        'cabbage', 'cachecoin', 'californium', 'caliphcoin', 'campuscoin',
#        'cannabiscoin', 'cannacoin', 'cannation', 'canyacoin', 'cappasity',
#        'capricoin', 'carboncoin', 'cardano', 'carvertical', 'cashcoin',
#        'catcoin', 'ccminer', 'ccore', 'centra', 'centurion', 'chaincoin',
#        'chainlink', 'chancoin', 'change', 'chesscoin', 'chips',
#        'chronobank', 'chronologic', 'chronos', 'cindicator', 'civic',
#        'clams', 'clearpoll', 'cloakcoin', 'cobinhood', 'coexistcoin',
#        'coindash', 'coinlancer', 'coinmeet', 'coinonat', 'coinonatx',
#        'colossuscoinxt', 'comet', 'compucoin', 'concoin', 'condensate',
#        'confido', 'copico', 'corethum', 'coss', 'counterparty',
#        'coupecoin', 'covesting', 'cream', 'creatio', 'creativecoin',
#        'creditbit', 'credo', 'crevacoin', 'crowdcoin', 'crown', 'crtcoin',
#        'crypto', 'cryptocarbon', 'cryptoescudo', 'cryptoforecast',
#        'cryptojacks', 'cryptonex', 'cryptonite', 'cryptopay',
#        'cryptoping', 'curecoin', 'cvcoin', 'cybcsec', 'cybermiles',
#        'cypher', 'dai', 'dalecoin', 'dappster', 'darcrus', 'darsek',
#        'dash', 'dashcoin', 'databits', 'datum', 'daxxcoin', 'dcorp',
#        'debitcoin', 'decent', 'decentraland', 'decred', 'deeponion',
#        'delphy', 'dent', 'dentacoin', 'desire', 'destiny', 'devery',
#        'dew', 'dfscoin', 'diamond', 'dibcoin', 'digibyte', 'digicube',
#        'digipulse', 'digitalcoin', 'digitalnote', 'digitalprice',
#        'digixdao', 'dimecoin', 'dinastycoin', 'district0x', 'divi',
#        'dnotes', 'dogecoin', 'dollarcoin', 'domraider', 'dopecoin',
#        'dotcoin', 'dovu', 'draftcoin', 'dragonchain', 'dreamcoin',
#        'droxne', 'dynamic', 'e-coin', 'e-gulden', 'eaglecoin',
#        'earthcoin', 'ecobit', 'ecocoin', 'edgeless', 'ego', 'eidoo',
#        'einsteinium', 'elastic', 'electra', 'electroneum', 'elementrem',
#        'elixir', 'ellaism', 'eltcoin', 'elysium', 'embers', 'emercoin',
#        'emphy', 'encrypgen', 'energo', 'energycoin', 'enigma', 'eos',
#        'equitrader', 'erc20', 'ereal', 'ergo', 'eroscoin', 'eryllium',
#        'espers', 'eternity', 'ethbet', 'ethbits', 'ethereum', 'etheriya',
#        'etheroll', 'etherparty', 'ethgas', 'ethlend', 'ethorse', 'ethos',
#        'eurocoin', 'europecoin', 'eventchain', 'everex', 'evergreencoin',
#        'everus', 'evotion', 'exchangen', 'exclusivecoin', 'expanse',
#        'exrnchain', 'factom', 'faircoin', 'fantomcoin', 'farad',
#        'fastcoin', 'feathercoin', 'fedoracoin', 'fimkrypto', 'fincoin',
#        'firecoin', 'firstblood', 'firstcoin', 'flash', 'flaxscript',
#        'flik', 'flixxo', 'florincoin', 'fluttercoin', 'flycoin', 'flypme',
#        'foldingcoin', 'force', 'franko', 'freicoin', 'fucktoken',
#        'fuelcoin', 'fujicoin', 'fujinto', 'funcoin', 'fundyourselfnow',
#        'funfair', 'fuzzballs', 'gaia', 'gambit', 'gamecredits',
#        'gameunits', 'ganjacoin', 'gapcoin', 'garlicoin', 'gas', 'gatcoin',
#        'gbcgoldcoin', 'geertcoin', 'geysercoin', 'gifto', 'gimli',
#        'globalboost-y', 'globalcoin', 'globaltoken', 'gobyte',
#        'goldblocks', 'goldcoin', 'goldpieces', 'goldreserve', 'golos',
#        'goodomy', 'greencoin', 'gridcoin', 'grimcoin', 'groestlcoin',
#        'guccionecoin', 'gulden', 'guncoin', 'gxshares', 'hacken',
#        'halcyon', 'happycoin', 'healthywormcoin', 'hedge', 'helleniccoin',
#        'hellogold', 'hempcoin', 'herocoin', 'hexx', 'hicoin', 'hitcoin',
#        'hive', 'hobonickels', 'hodlcoin', 'hollywoodcoin',
#        'homeblockcoin', 'honey', 'hshare', 'htmlcoin', 'humaniq',
#        'huntercoin', 'hush', 'hyperstake', 'i0coin', 'ibank', 'icobid',
#        'icoin', 'icon', 'iconic', 'iconomi', 'icos', 'idice', 'iethereum',
#        'ignis', 'impact', 'impulsecoin', 'incakoin', 'incent', 'indahash',
#        'inflationcoin', 'influxcoin', 'ink', 'innova', 'inpay',
#        'insurepal', 'intensecoin', 'internxt', 'investfeed', 'ion',
#        'iostoken', 'iota', 'islacoin', 'iticoin', 'iungo', 'ixcoin',
#        'ixledger', 'janus', 'jetcoin', 'jewels', 'jinn', 'jobscoin',
#        'joincoin', 'joulecoin', 'karma', 'kayicoin', 'kekcoin',
#        'kilocoin', 'kin', 'kobocoin', 'kolion', 'komodo', 'kronecoin',
#        'kurrent', 'kushcoin', 'lamden', 'lampix', 'lanacoin', 'latoken',
#        'leacoin', 'lendconnect', 'leocoin', 'letitride', 'leverj',
#        'leviarcoin', 'levoplus', 'life', 'linda', 'linx', 'lisk',
#        'litebar', 'litebitcoin', 'litecoin', 'litecred', 'litedoge',
#        'lockchain', 'lomocoin', 'loopring', 'luckchain', 'lunyr',
#        'luxcoin', 'lykke', 'machinecoin', 'macron', 'madcoin', 'maecenas',
#        'magi', 'magiccoin', 'magnet', 'magnum', 'maidsafecoin', 'maker',
#        'marijuanacoin', 'marscoin', 'martexcoin', 'masternodecoin',
#        'maxcoin', 'mcap', 'medibloc', 'medishares', 'megacoin', 'melon',
#        'mercury', 'metal', 'metalcoin', 'micromoney', 'milocoin',
#        'mincoin', 'mindcoin', 'minereum', 'mineum', 'minexcoin',
#        'mintcoin', 'mobilego', 'modum', 'moin', 'mojocoin', 'monaco',
#        'monacoin', 'monero', 'monetaryunit', 'monetha', 'money',
#        'mooncoin', 'mothership', 'motocoin', 'musicoin', 'mustangcoin',
#        'myriad', 'mysterium', 'mywish', 'naga', 'namecoin', 'neblio',
#        'nekonium', 'nem', 'neo', 'neoscoin', 'netcoin', 'netko',
#        'neumark', 'neuro', 'neutron', 'nevacoin', 'neverdie', 'newbium',
#        'newyorkcoin', 'nexium', 'nexus', 'nimfamoney', 'nimiq',
#        'noblecoin', 'nodecoin', 'nolimitcoin', 'novacoin', 'nubits',
#        'nuls', 'numeraire', 'nushares', 'nvo', 'nxt', 'nyancoin', 'oax',
#        'obits', 'obsidian', 'oceanlab', 'octanox', 'octocoin', 'odyssey',
#        'okcash', 'omisego', 'omni', 'onix', 'opal', 'opus', 'oraclechain',
#        'orbitcoin', 'origintrail', 'orlycoin', 'osmiumcoin', 'oxycoin',
#        'oyster', 'p7coin', 'paccoin', 'pakcoin', 'paragon',
#        'parallelcoin', 'parkbyte', 'particl', 'patientory', 'paycon',
#        'payfair', 'paypex', 'paypie', 'peercoin', 'pesetacoin',
#        'petrodollar', 'phoenixcoin', 'phore', 'photon', 'piecoin',
#        'piggycoin', 'pillar', 'pinkcoin', 'piplcoin', 'pirl', 'pivx',
#        'pizzacoin', 'platinumbar', 'playercoin', 'playkey', 'plncoin',
#        'pluscoin', 'pluton', 'polis', 'polybius', 'ponzicoin',
#        'popularcoin', 'populous', 'posex', 'postcoin', 'postoken',
#        'potcoin', 'prcoin', 'presearch', 'primas', 'prime-xi',
#        'primecoin', 'printerium', 'privatix', 'prizm', 'prochain',
#        'procurrency', 'project-x', 'propy', 'prototanium', 'publica',
#        'pulse', 'pura', 'pure', 'purevidz', 'putincoin', 'px', 'qash',
#        'qbao', 'qbic', 'qlink', 'qtum', 'quantstamp', 'quantum', 'quark',
#        'quatloo', 'quazarcoin', 'qubitcoin', 'quebecoin', 'qunqun',
#        'qvolta', 'qwark', 'radium', 'ratecoin', 'rchain', 'real',
#        'redcoin', 'reddcoin', 'reecoin', 'regalcoin', 'remicoin', 'renos',
#        'revain', 'revolvercoin', 'rialto', 'riecoin', 'rimbit', 'ripple',
#        'rise', 'rivetz', 'ronpaulcoin', 'roofs', 'roulettetoken',
#        'rsgpcoin', 'rubies', 'rubycoin', 'rupaya', 'rupee', 'russiacoin',
#        'rustbits', 'sacoin', 'sagacoin', 'salt', 'salus', 'sativacoin',
#        'satoshimadness', 'scorecoin', 'secretcoin', 'securecoin',
#        'selfiecoin', 'selfkey', 'senderon', 'sequence', 'sexcoin',
#        'shadowcash', 'sharechain', 'shift', 'shilling', 'shorty',
#        'siacoin', 'sibcoin', 'signatum', 'singulardtv', 'singularitynet',
#        'sixeleven', 'skeincoin', 'skincoin', 'skycoin', 'slevin',
#        'smartbillions', 'smartcash', 'smartcoin', 'smileycoin', 'snovio',
#        'soarcoin', 'social', 'soilcoin', 'sojourn', 'solarcoin',
#        'solarflarecoin', 'solaris', 'soma', 'songcoin', 'sonm',
#        'sooncoin', 'sophiatx', 'spacecoin', 'spankchain', 'spectrecoin',
#        'speedcash', 'sphere', 'sportyco', 'spots', 'spreadcoin',
#        'sprouts', 'sproutsextreme', 'starbase', 'starcredits', 'starta',
#        'startcoin', 'status', 'stealthcoin', 'steem', 'stellar', 'steps',
#        'sterlingcoin', 'storj', 'storm', 'stox', 'straks', 'stratis',
#        'substratum', 'sumokoin', 'suncontract', 'supercoin', 'suretly',
#        'swagbucks', 'swftcoin', 'swing', 'sydpak', 'syndicate', 'synereo',
#        'synergy', 'syscoin', 'taas', 'tagcoin', 'tagrcoin', 'tajcoin',
#        'tao', 'tekcoin', 'telcoin', 'tenx', 'terracoin', 'teslacoin',
#        'tether', 'thegcccoin', 'tierion', 'tigercoin', 'titcoin',
#        'tittiecoin', 'toacoin', 'tokencard', 'tokes', 'tokyo', 'tracto',
#        'transfercoin', 'trezarcoin', 'triangles', 'triggers', 'trollcoin',
#        'tron', 'truckcoin', 'trueflip', 'trumpcoin', 'trustplus',
#        'tychocoin', 'ubiq', 'ulatech', 'ultracoin', 'unbreakablecoin',
#        'unicoin', 'unify', 'unitus', 'universe', 'unobtanium',
#        'unrealcoin', 'upfiring', 'uro', 'utrust', 'valorbit',
#        'vaperscoin', 'vcash', 'vechain', 'veltor', 'verge', 'vericoin',
#        'verify', 'veritaseum', 'veriumreserve', 'veros', 'version',
#        'vertcoin', 'viacoin', 'vibe', 'viberate', 'virtacoin',
#        'virtacoinplus', 'virtualcoin', 'visio', 'viuly', 'vivo',
#        'votecoin', 'voxels', 'vslice', 'vtorrent', 'wabi', 'wagerr',
#        'walton', 'wandx', 'warp', 'waves', 'wavesgo', 'wax', 'wayguide',
#        'whalecoin', 'whitecoin', 'wings', 'woodcoin', 'worldcoin',
#        'worldcore', 'x-coin', 'xaurum', 'xenon', 'xgox', 'xios',
#        'xonecoin', 'xplay', 'xtrabytes', 'yacoin', 'yenten', 'yocoin',
#        'yoyow', 'zayedcoin', 'zcash', 'zclassic', 'zcoin', 'zeitcoin',
#        'zencash', 'zennies', 'zephyr', 'zero', 'zetacoin', 'zetamicron',
#        'zeusshield', 'zilliqa', 'zoin', 'zonecoin', 'zozocoin', 'zrcoin',
#        'zurcoin'], dtype=object)

# %%
x = 'encrypto'

# %%
list(filter(lambda l: x in l, list(trend.currency.unique())))
# Out:
# ['encryptotel-eth', 'encryptotel']

# %%
list(filter(lambda l: x in l, list(df.name.apply(str.lower))))
# Out:
# ['encryptotel [...', 'encryptotel [...']
