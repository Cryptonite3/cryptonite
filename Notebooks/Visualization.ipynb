# %%
import pandas as pd
import plotly.express as px

# %%
df1 = pd.read_csv('../Data/all_currencies_table.csv')
df2 = pd.read_csv('../Data/clean_cryptocurrency_prices_by_date.csv')
print(df1.columns,df2.columns)
# Out:
# Index(['number', 'name', 'symbol', 'market_cap', 'price', 'circulating_supply',
#        'volume_24hr', '1h', '24h', '7d'],
#       dtype='object') Index(['Unnamed: 0', 'Coin', 'Date', 'Price'], dtype='object')

# %%
px.scatter(x=df1.market_cap,y=df1.volume_24hr)
